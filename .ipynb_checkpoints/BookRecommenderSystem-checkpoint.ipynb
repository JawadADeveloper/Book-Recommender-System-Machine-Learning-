# %% [markdown]
# # Book Recommender System

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
import re
import nltk
from nltk.corpus import stopwords
from wordcloud import WordCloud, STOPWORDS


# Download the stopwords from NLTK
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\VICTUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Types Of Recommender Systems
# Popularity Based
# Content Based 
# Collaborative based 
# Recommender System 
# hybride System

# %%
books = pd.read_csv('books.csv')
users = pd.read_csv('users.csv')
ratings = pd.read_csv('ratings.csv')
# Out:
# C:\Users\VICTUS\AppData\Local\Temp\ipykernel_228060\3819754567.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books = pd.read_csv('books.csv')

# %%
books.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...

# %%
users.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
print(books.shape)
print(users.shape)
print(ratings.shape)
# Out:
# (271360, 8)
# (278858, 3)
# (1149780, 3)

# %%
books['Year-Of-Publication'].unique()
# Out:
# array([2002, 2001, 1991, 1999, 2000, 1993, 1996, 1988, 2004, 1998, 1994,
#        2003, 1997, 1983, 1979, 1995, 1982, 1985, 1992, 1986, 1978, 1980,
#        1952, 1987, 1990, 1981, 1989, 1984, 0, 1968, 1961, 1958, 1974,
#        1976, 1971, 1977, 1975, 1965, 1941, 1970, 1962, 1973, 1972, 1960,
#        1966, 1920, 1956, 1959, 1953, 1951, 1942, 1963, 1964, 1969, 1954,
#        1950, 1967, 2005, 1957, 1940, 1937, 1955, 1946, 1936, 1930, 2011,
#        1925, 1948, 1943, 1947, 1945, 1923, 2020, 1939, 1926, 1938, 2030,
#        1911, 1904, 1949, 1932, 1928, 1929, 1927, 1931, 1914, 2050, 1934,
#        1910, 1933, 1902, 1924, 1921, 1900, 2038, 2026, 1944, 1917, 1901,
#        2010, 1908, 1906, 1935, 1806, 2021, '2000', '1995', '1999', '2004',
#        '2003', '1990', '1994', '1986', '1989', '2002', '1981', '1993',
#        '1983', '1982', '1976', '1991', '1977', '1998', '1992', '1996',
#        '0', '1997', '2001', '1974', '1968', '1987', '1984', '1988',
#        '1963', '1956', '1970', '1985', '1978', '1973', '1980', '1979',
#        '1975', '1969', '1961', '1965', '1939', '1958', '1950', '1953',
#        '1966', '1971', '1959', '1972', '1955', '1957', '1945', '1960',
#        '1967', '1932', '1924', '1964', '2012', '1911', '1927', '1948',
#        '1962', '2006', '1952', '1940', '1951', '1931', '1954', '2005',
#        '1930', '1941', '1944', 'DK Publishing Inc', '1943', '1938',
#        '1900', '1942', '1923', '1920', '1933', 'Gallimard', '1909',
#        '1946', '2008', '1378', '2030', '1936', '1947', '2011', '2020',
#        '1919', '1949', '1922', '1897', '2024', '1376', '1926', '2037'],
#       dtype=object)

# %%
books.isnull().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            2
# Year-Of-Publication    0
# Publisher              2
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            3
# dtype: int64

# %%
users.isnull().sum()
# Out:
# User-ID          0
# Location         0
# Age         110762
# dtype: int64

# %%
users['Age']= users['Age'].fillna(users['Age'].mean())
users['Age'] = users['Age'].astype(np.int64)

# %%
ratings.isnull().sum()
# Out:
# User-ID        0
# ISBN           0
# Book-Rating    0
# dtype: int64

# %%
books.duplicated().sum()
# Out:
# np.int64(0)

# %%
users.duplicated().sum()
# Out:
# np.int64(0)

# %%
ratings.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Summary statistics for numerical columns
print("Books Data Statistics:")
books.describe()
# Out:
# Books Data Statistics:
#               ISBN      Book-Title      Book-Author  Year-Of-Publication  \
# count       271360          271360           271358               271360
# unique      271360          242135           102022                  202
# top     020130998X  Selected Poems  Agatha Christie                 2002
# freq             1              27              632                13903
#
#         Publisher                                        Image-URL-S  \
# count      271358                                             271360
# unique      16807                                             271044
# top     Harlequin  http://images.amazon.com/images/P/155936078X.0...
# freq         7535                                                  2
#
#                                               Image-URL-M  \
# count                                              271360
# unique                                             271044
# top     http://images.amazon.com/images/P/155936078X.0...
# freq                                                    2
#
#                                               Image-URL-L
# count                                              271357
# unique                                             271041
# top     http://images.amazon.com/images/P/155936078X.0...
# freq                                                    2

# %%
ratings['Book-Rating'].unique()
# Out:
# array([ 0,  5,  3,  6,  8,  7, 10,  9,  4,  1,  2])

# %%
n_users = users.shape[0]
n_books = books.shape[0]
print(n_users * n_books)
# Out:
# 75670906880

# %%
print("\nRatings Data Statistics:")
ratings.describe()
# Out:
# Ratings Data Statistics:
#             User-ID   Book-Rating
# count  1.149780e+06  1.149780e+06
# mean   1.403864e+05  2.866950e+00
# std    8.056228e+04  3.854184e+00
# min    2.000000e+00  0.000000e+00
# 25%    7.034500e+04  0.000000e+00
# 50%    1.410100e+05  0.000000e+00
# 75%    2.110280e+05  7.000000e+00
# max    2.788540e+05  1.000000e+01

# %%
# Value counts for categorical variables (example: book authors)
count = pd.DataFrame(books['Book-Author'].value_counts().head(10))

# %%
ratings_new = ratings[ratings['ISBN'].isin(books['ISBN'])]

# %%
merged_data = pd.merge(books, ratings_new, on='ISBN')
merged_data =  merged_data.sort_values('ISBN', ascending=True)
merged_data.head()
# Out:
#                ISBN                                         Book-Title  \
# 1013651  0000913154  The Way Things Work: An Illustrated Encycloped...
# 968138   0001010565                                    Mog's Christmas
# 968139   0001010565                                    Mog's Christmas
# 542150   0001046438                                               Liar
# 788100   0001046713                       Twopence to Cross the Mersey
#
#                            Book-Author Year-Of-Publication  \
# 1013651  C. van Amerongen (translator)                1967
# 968138                     Judith Kerr                1992
# 968139                     Judith Kerr                1992
# 542150                     Stephen Fry                   0
# 788100                 Helen Forrester                1992
#
#                         Publisher  \
# 1013651      Simon &amp; Schuster
# 968138                    Collins
# 968139                    Collins
# 542150           Harpercollins Uk
# 788100   HarperCollins Publishers
#
#                                                Image-URL-S  \
# 1013651  http://images.amazon.com/images/P/0000913154.0...
# 968138   http://images.amazon.com/images/P/0001010565.0...
# 968139   http://images.amazon.com/images/P/0001010565.0...
# 542150   http://images.amazon.com/images/P/0001046438.0...
# 788100   http://images.amazon.com/images/P/0001046713.0...
#
#                                                Image-URL-M  \
# 1013651  http://images.amazon.com/images/P/0000913154.0...
# 968138   http://images.amazon.com/images/P/0001010565.0...
# 968139   http://images.amazon.com/images/P/0001010565.0...
# 542150   http://images.amazon.com/images/P/0001046438.0...
# 788100   http://images.amazon.com/images/P/0001046713.0...
#
#                                                Image-URL-L  User-ID  \
# 1013651  http://images.amazon.com/images/P/0000913154.0...   171118
# 968138   http://images.amazon.com/images/P/0001010565.0...    86123
# 968139   http://images.amazon.com/images/P/0001010565.0...   209516
# 542150   http://images.amazon.com/images/P/0001046438.0...    23902
# 788100   http://images.amazon.com/images/P/0001046713.0...   196149
#
#          Book-Rating
# 1013651            8
# 968138             0
# 968139             0
# 542150             9
# 788100             0

# %%
most_read = books['Book-Title'].value_counts().reset_index()
most_read.columns = ['Book-Title','count']

plt.figure(figsize = (10,10))
plt.title("Most Read Books")
sns.barplot(x = 'count', y = 'Book-Title', data = most_read.head(30));

# %%
top_rated = merged_data[['Book-Title','Book-Rating']]
top_rated = top_rated.groupby('Book-Title', as_index=False)['Book-Rating'].mean()
top_rated = top_rated.sort_values(['Book-Rating'],ascending=False).reset_index()
top_rated = top_rated[['Book-Title','Book-Rating']]

top_rated.head()
# Out:
#                                           Book-Title  Book-Rating
# 0  Timelock: How Life Got So Hectic and What You ...         10.0
# 1                         Timelines of World History         10.0
# 2                                 Bathroom Game Book         10.0
# 3        Rookie Princess (Silhouette Desire, No 483)         10.0
# 4                                         Roof World         10.0

# %%
top_rated.tail()
# Out:
#                                                Book-Title  Book-Rating
# 241066                                     name the baby.          0.0
# 241067                                      namedropping.          0.0
# 241068                                         net future          0.0
# 241069                   'Twas the Night Before Christmas          0.0
# 241070   Harry Potter and the Bible: The Menace Behind...          0.0

# %%
top_author = books['Book-Author'].value_counts().reset_index()
top_author.columns = ['Author', 'count']
top_author['Author'] = top_author['Author']
top_author = top_author.sort_values('count',ascending=False)

plt.figure(figsize=(12,10))
plt.title('Top 30 Authors according to most books')
sns.barplot(data = top_author.head(30), x = 'count', y = 'Author');

# %%
top_publisher = books['Publisher'].value_counts().reset_index()
top_publisher.columns = ['Publisher', 'count']
top_publisher['Publisher'] = top_publisher['Publisher']
top_publisher = top_publisher.sort_values('count',ascending=False)

plt.figure(figsize=(12,10))
plt.title('Top 30 Publishers according to most books')
sns.barplot(data = top_publisher.head(30), x = 'count', y = 'Publisher');

# %%
user_age = users['Age']
plt.figure(figsize=(10,6), tight_layout=True)
plt.title('Number of users according to user age')
sns.histplot(user_age, bins=25, linewidth = 2, color = 'cyan', edgecolor = 'black');

# %%
# Get the English stop words list
stop_words = set(stopwords.words('english'))

# Example text data (could be book titles or any other text)
text_data = books['Book-Title']

# Function to remove stop words
def remove_stopwords(text):
    # Convert text to lowercase
    text = text.lower()
    # Remove punctuation
    text = re.sub(r'[^\w\s]', '', text)
    # Split text into words
    words = text.split()
    # Remove stop words
    filtered_words = [word for word in words if word not in stop_words]
    # Join the words back into a string
    return ' '.join(filtered_words)

# Apply the function to the text column
books['Book-Title'] = books['Book-Title'].apply(remove_stopwords)

books.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                classical mythology
# 1  0002005018                                       clara callan
# 2  0060973129                                  decision normandy
# 3  0374157065  flu story great influenza pandemic 1918 search...
# 4  0393045218                                    mummies urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...

# %%
author_string = " ".join(books['Book-Author'].astype(str))
title_string = " ".join(books['Book-Title'].astype(str))
publisher_string = " ".join(books['Publisher'].astype(str))
stop_words = set(STOPWORDS)

def wordcloud(string,title ="unknown"):
    wc = WordCloud(width=800,height=500,mask=None,random_state=21,
                   stopwords=stop_words).generate(string)
    fig=plt.figure(figsize=(16,8))
    plt.title(title)
    plt.axis('off')
    plt.imshow(wc)

# %%
wordcloud(author_string,'Author Name words')

# %%
wordcloud(title_string,'Title text words')

# %%
wordcloud(publisher_string,'Publisher Name words')

# %%
# Combine all book titles into a single string
all_titles = ' '.join(books['Book-Title'].dropna().values)

# Simple text cleaning
all_titles = re.sub(r'[^\w\s]', '', all_titles).lower()

# Split into words and count frequency
word_counts = Counter(all_titles.split())
common_words = word_counts.most_common(10)

print("\nMost Common Words in Book Titles:")
pd.DataFrame(common_words)
# Out:
# Most Common Words in Book Titles:
#            0      1
# 0       book  12110
# 1      guide   7132
# 2      novel   6639
# 3       life   6120
# 4     series   6055
# 5  harlequin   5640
# 6       love   5212
# 7        amp   5061
# 8    stories   4947
# 9        new   4649

# %%
# Create a Popularity Score based on number of ratings and average rating
books['popularity_score'] = books['ISBN'].map(popular_books) * books['ISBN'].map(average_ratings)

# Display the books with the highest popularity score
pd.DataFrame(books[['Book-Title', 'popularity_score']].sort_values(by='popularity_score', ascending=False).head(10))
# Out:
#                                 Book-Title  popularity_score
# 408                     lovely bones novel            5787.0
# 748                          da vinci code            4108.0
# 522          red tent bestselling backlist            3134.0
# 356                       secret life bees            2595.0
# 26                             wild animus            2551.0
# 1105  divine secrets yaya sisterhood novel            2524.0
# 118                      angels amp demons            2179.0
# 305                          painted house            2062.0
# 1922                   snow falling cedars            1999.0
# 0                      classical mythology               NaN

# %%
ratings_with_name = merged_data[:]

# %%
num_rating_df = ratings_with_name.groupby('Book-Title').count()['Book-Rating'].reset_index()
num_rating_df.rename(columns={'Book-Rating': 'num_ratings'}, inplace=True)
num_rating_df
# Out:
#                                                Book-Title  num_ratings
# 0        A Light in the Storm: The Civil War Diary of ...            4
# 1                                   Always Have Popsicles            1
# 2                    Apple Magic (The Collector's series)            1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...            1
# 4        Beyond IBM: Leadership Marketing and Finance ...            1
# ...                                                   ...          ...
# 241066                                      Ã?Â?lpiraten.            2
# 241067                     Ã?Â?rger mit Produkt X. Roman.            4
# 241068                                Ã?Â?sterlich leben.            1
# 241069                              Ã?Â?stlich der Berge.            3
# 241070                                  Ã?Â?thique en toc            2
#
# [241071 rows x 2 columns]

# %%
avg_rating_df = ratings_with_name.groupby('Book-Title')['Book-Rating'].agg(lambda x: x.astype(float).mean()).reset_index()
avg_rating_df.rename(columns = {'Book-Rating' : 'avg_rating'}, inplace = True)
avg_rating_df
# Out:
#                                                Book-Title  avg_rating
# 0        A Light in the Storm: The Civil War Diary of ...    2.250000
# 1                                   Always Have Popsicles    0.000000
# 2                    Apple Magic (The Collector's series)    0.000000
# 3        Ask Lily (Young Women of Faith: Lily Series, ...    8.000000
# 4        Beyond IBM: Leadership Marketing and Finance ...    0.000000
# ...                                                   ...         ...
# 241066                                      Ã?Â?lpiraten.    0.000000
# 241067                     Ã?Â?rger mit Produkt X. Roman.    5.250000
# 241068                                Ã?Â?sterlich leben.    7.000000
# 241069                              Ã?Â?stlich der Berge.    2.666667
# 241070                                  Ã?Â?thique en toc    4.000000
#
# [241071 rows x 2 columns]

# %%
popular_df = num_rating_df.merge(avg_rating_df, on='Book-Title').drop_duplicates('Book-Title')

# %%
popular_df
# Out:
#                                                Book-Title  num_ratings  \
# 0        A Light in the Storm: The Civil War Diary of ...            4
# 1                                   Always Have Popsicles            1
# 2                    Apple Magic (The Collector's series)            1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...            1
# 4        Beyond IBM: Leadership Marketing and Finance ...            1
# ...                                                   ...          ...
# 241066                                      Ã?Â?lpiraten.            2
# 241067                     Ã?Â?rger mit Produkt X. Roman.            4
# 241068                                Ã?Â?sterlich leben.            1
# 241069                              Ã?Â?stlich der Berge.            3
# 241070                                  Ã?Â?thique en toc            2
#
#         avg_rating
# 0         2.250000
# 1         0.000000
# 2         0.000000
# 3         8.000000
# 4         0.000000
# ...            ...
# 241066    0.000000
# 241067    5.250000
# 241068    7.000000
# 241069    2.666667
# 241070    4.000000
#
# [241071 rows x 3 columns]

# %%
popular_df=popular_df[popular_df['num_ratings'] >= 250].sort_values('avg_rating', ascending=False).head(50)

# %%
popular_df=popular_df.merge(books,on='Book-Title')[['Book-Title','Book-Author','Image-URL-M','num_ratings', 'avg_rating']]

# %%
popular_df
# Out:
#    Book-Title    Book-Author  \
# 0        1984  George Orwell
# 1        1984  George Orwell
# 2        1984  George Orwell
# 3        1984  George Orwell
# 4        1984  George Orwell
# 5        1984  George Orwell
# 6        1984  George Orwell
# 7        1984  George Orwell
# 8        1984  George Orwell
# 9        1984  George Orwell
# 10       1984  George Orwell
#
#                                           Image-URL-M  num_ratings  avg_rating
# 0   http://images.amazon.com/images/P/0451524934.0...          284    4.454225
# 1   http://images.amazon.com/images/P/0451519841.0...          284    4.454225
# 2   http://images.amazon.com/images/P/0452262933.0...          284    4.454225
# 3   http://images.amazon.com/images/P/0151660387.0...          284    4.454225
# 4   http://images.amazon.com/images/P/848328006X.0...          284    4.454225
# 5   http://images.amazon.com/images/P/207036822X.0...          284    4.454225
# 6   http://images.amazon.com/images/P/8423328651.0...          284    4.454225
# 7   http://images.amazon.com/images/P/3548234100.0...          284    4.454225
# 8   http://images.amazon.com/images/P/B00006H3BO.0...          284    4.454225
# 9   http://images.amazon.com/images/P/3453164210.0...          284    4.454225
# 10  http://images.amazon.com/images/P/0582060184.0...          284    4.454225

# %% [markdown]
# ## Collaborative Filtering Based Recommender System

# %%
x = ratings_with_name.groupby('User-ID').count()['Book-Rating']>200
x[x].index
# Out:
# Index([   254,   2276,   2766,   2977,   3363,   4017,   4385,   6251,   6323,
#          6543,
#        ...
#        271705, 273979, 274004, 274061, 274301, 274308, 275970, 277427, 277639,
#        278418],
#       dtype='int64', name='User-ID', length=811)

# %%
filtered_rating = ratings_with_name[ratings_with_name['User-ID'].isin(x[x].index)]

# %%
y=filtered_rating.groupby('Book-Title').count()['Book-Rating']>=50

# %%
famous_books = y[y].index

# %%
final_rating = filtered_rating[filtered_rating['Book-Title'].isin(famous_books)]

# %%
pt = final_rating.pivot_table(index='Book-Title', columns='User-ID', values='Book-Rating')

# %%
pt.shape
# Out:
# (706, 810)

# %%
pt.fillna(0,inplace=True)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity_scores = cosine_similarity(pt)

# %%
similarity_scores.shape
# Out:
# (706, 706)

# %%
# from scipy.sparse import csr_matrix
# from sklearn.neighbors import NearestNeighbors
# book_sparse=csr_matrix(pt)
# model=NearestNeighbors(metric='cosine',algorithm='brute')
# model.fit(book_sparse)

# %%
def recommend(book_name):
    # index fetch
    index = np.where(pt.index==book_name)[0][0]
    similar_items = sorted(list(enumerate(similarity_scores[index])),key=lambda x:x[1],reverse=True)[1:5]
    
    data = []
    for i in similar_items:
        item = []
        temp_df = books[books['Book-Title'] == pt.index[i[0]]]
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Title'].values))
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Author'].values))
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Image-URL-M'].values))
        
        data.append(item)
    
    return data

# %%
recommend('1984')
# Out:
# [[], [], [], []]

# %%
books.drop_duplicates('Book-Title')

# %%
import pickle
pickle.dump(popular_df,open('popular.pkl','wb'))
pickle.dump(pt,open('pt.pkl','wb'))
pickle.dump(books,open('books.pkl','wb'))
pickle.dump(similarity_scores,open('similarity_scores.pkl','wb'))
